# %% [markdown]
# ## Import libiraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Extract data

# %%
! unzip "/content/Online Retail.xlsx.zip" -d ""
# Out:
# Archive:  /content/Online Retail.xlsx.zip
#   inflating: Online Retail.xlsx

# %% [markdown]
# ## Read data

# %%
clint_demo = pd.read_excel('/content/Online Retail.xlsx')
clint_demo.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# ## knowing all information about data

# %%
clint_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ## Check missing values

# %%
clint_demo.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ## Handling the missing values

# %%
clint_demo[clint_demo['Description'].isna()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
clint_demo[clint_demo['Description'].isna()].index
# Out:
# Index([   622,   1970,   1971,   1972,   1987,   1988,   2024,   2025,   2026,
#          2406,
#        ...
#        524473, 524475, 529667, 533711, 533712, 535322, 535326, 535332, 536981,
#        538554],
#       dtype='int64', length=1454)

# %%
clint_demo.drop(clint_demo[clint_demo['Description'].isna()].index, inplace = True)
clint_demo.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
clint_demo['CustomerID'].fillna('Missing', inplace = True)
clint_demo.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ## Handling the duplicated values

# %%
clint_demo.duplicated().sum()
# Out:
# 5268

# %%
clint_demo.drop_duplicates(inplace = True)
clint_demo.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Separate time from date and reorderd columns

# %%
clint_demo['InvoiceTime'] = clint_demo['InvoiceDate'].dt.time
clint_demo['InvoiceDate'] = clint_demo['InvoiceDate'].dt.date
reorder_columns = ['CustomerID', 'InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'InvoiceTime', 'UnitPrice', 'Country']
clint_demo = clint_demo[reorder_columns]

# %%
clint_demo.head(10)
# Out:
#    CustomerID InvoiceNo StockCode                          Description  \
# 0     17850.0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1     17850.0    536365     71053                  WHITE METAL LANTERN
# 2     17850.0    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3     17850.0    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4     17850.0    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5     17850.0    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 6     17850.0    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7     17850.0    536366     22633               HAND WARMER UNION JACK
# 8     17850.0    536366     22632            HAND WARMER RED POLKA DOT
# 9     13047.0    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#    Quantity InvoiceDate InvoiceTime  UnitPrice         Country
# 0         6  2010-12-01    08:26:00       2.55  United Kingdom
# ...

# %% [markdown]
# ## Descriptive statistics

# %%
clint_demo.describe(include = 'number').T
# Out:
#                count          mean          std       min       25%       50%  \
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
#
#                  75%      max
# CustomerID  16791.00  18287.0
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0

# %%
clint_demo.describe(include = 'object')
# Out:
#         InvoiceNo StockCode                         Description InvoiceDate  \
# count      541909    541909                              540455      541909
# unique      25900      4070                                4223         305
# top        573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER  2011-12-05
# freq         1114      2313                                2369        5331
#
#        InvoiceTime         Country
# count       541909          541909
# unique         774              38
# top       15:56:00  United Kingdom
# freq          2628          495478

# %% [markdown]
# ## Export the data

# %%
clint_demo.to_excel('clint_demo_clean.xlsx', index = False)

# %%
clint_demo_clean = pd.read_excel('/content/clint_demo_clean.xlsx')
clint_demo_clean.head(10)
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5           5    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 6           6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7           7    536366     22633               HAND WARMER UNION JACK
# 8           8    536366     22632            HAND WARMER RED POLKA DOT
# 9           9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#    Quantity         InvoiceDate  UnitPrice CustomerID         Country
# 0         6 2010-12-01 08:26:00       2.55      17850  United Kingdom
# ...

# %% [markdown]
# ## Customer segmentation (RFM technique)

# %%
# Calculate Recency (days since last purchase)
max_date = clint_demo_clean['InvoiceDate'].max()
recency = clint_demo_clean.groupby('CustomerID')['InvoiceDate'].max().reset_index(name='LastPurchaseDate')
recency['Recency'] = (max_date - recency['LastPurchaseDate']).dt.days

# Calculate Frequency (unique InvoiceNo per CustomerID)
frequency = clint_demo_clean.groupby('CustomerID')['InvoiceNo'].nunique().reset_index(name='Frequency')

# Calculate Monetary (Quantity * UnitPrice)
clint_demo_clean['Monetary'] = clint_demo_clean['Quantity'] * clint_demo_clean['UnitPrice']

# Calculate Monetary (total spend per customer)
monetary = clint_demo_clean.groupby('CustomerID')['Monetary'].sum().reset_index(name='Monetary')

# Merge all RFM metrics
rfm = frequency.merge(recency[['CustomerID', 'Recency']], on='CustomerID')
rfm = rfm.merge(monetary, on='CustomerID')

# Change place of columns
rfm = rfm[['CustomerID', 'Recency', 'Frequency', 'Monetary']]

# Use display for interactive output in notebooks
display(rfm)

# Show the first few rows
rfm.head()
# Out:
#      CustomerID  Recency  Frequency    Monetary
# 0         12346      325          2        0.00
# 1         12347        1          7     4310.00
# 2         12348       74          4     1797.24
# 3         12349       18          1     1757.55
# 4         12350      309          1      334.40
# ...         ...      ...        ...         ...
# 4368      18281      180          1       80.82
# 4369      18282        7          3      176.60
# 4370      18283        3         16     2045.53
# 4371      18287       42          3     1837.28
# 4372    Missing        0       2256  1447487.53
#
# [4373 rows x 4 columns]
#   CustomerID  Recency  Frequency  Monetary
# 0      12346      325          2      0.00
# 1      12347        1          7   4310.00
# 2      12348       74          4   1797.24
# 3      12349       18          1   1757.55
# 4      12350      309          1    334.40

# %%
rfm.drop_duplicates('Frequency', inplace = True)
rfm.duplicated('Frequency').sum()
# Out:
# 0

# %%
rfm['r_score'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['f_score'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['m_score'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])

rfm.sample(5)
# Out:
#      CustomerID  Recency  Frequency   Monetary r_score f_score m_score
# 3014      16422       16         75   33805.69       1       4       4
# 1         12347        1          7    4310.00       4       1       1
# 1703      14646        1         77  279489.02       4       4       4
# 436       12901        8         36   16293.10       2       3       3
# 2798      16133        3         46   14305.66       3       3       3

# %%
rfm['rfm_score'] = rfm['r_score'].astype(str) + rfm['f_score'].astype(str) + rfm['m_score'].astype(str)
rfm['rfm_score'] = rfm['rfm_score'].astype(int)
rfm.head()
# Out:
#   CustomerID  Recency  Frequency  Monetary r_score f_score m_score  rfm_score
# 0      12346      325          2      0.00       1       1       1        111
# 1      12347        1          7   4310.00       4       1       1        411
# 2      12348       74          4   1797.24       1       1       1        111
# 3      12349       18          1   1757.55       1       1       1        111
# 5      12352       35         11   1545.41       1       1       1        111

# %%
rfm['customer_segmentation'] = pd.qcut(rfm['rfm_score'], 4, labels=['Bronze', 'Silver', 'Gold', 'Platinum'])
rfm.head()
# Out:
#   CustomerID  Recency  Frequency  Monetary r_score f_score m_score  rfm_score  \
# 0      12346      325          2      0.00       1       1       1        111
# 1      12347        1          7   4310.00       4       1       1        411
# 2      12348       74          4   1797.24       1       1       1        111
# 3      12349       18          1   1757.55       1       1       1        111
# 5      12352       35         11   1545.41       1       1       1        111
#
#   customer_segmentation
# 0                Bronze
# 1                  Gold
# 2                Bronze
# 3                Bronze
# 5                Bronze

# %%
rfm['customer_segmentation'].value_counts()
# Out:
# customer_segmentation
# Bronze      17
# Gold        17
# Silver      16
# Platinum    16
# Name: count, dtype: int64
